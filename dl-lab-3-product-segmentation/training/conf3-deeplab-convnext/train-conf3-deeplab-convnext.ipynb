# %%
# !pip install -q segmentation-models-pytorch

# %%
import os
import gc
import time
import random
from pathlib import Path

import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import StratifiedKFold

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
import segmentation_models_pytorch as smp

import albumentations as A
from albumentations.pytorch import ToTensorV2

# %%
# ==========================================
# 1. КОНФИГУРАЦИЯ И НАСТРОЙКИ
# ==========================================
DATA_ROOT = Path(r"/kaggle/input/competitions/dl-lab-3-product-segmentation/train")
IMAGES_DIR = DATA_ROOT / "images"
MASKS_DIR = DATA_ROOT / "masks"
SAVE_DIR = Path("/kaggle/working/models")
SAVE_DIR.mkdir(parents=True, exist_ok=True)

IMG_SIZE = 320
BATCH_SIZE = 32
EPOCHS = 80
N_SPLITS = 5
SEED = 42

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

def seed_everything(seed=42):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True

seed_everything(SEED)

# %%
# ==========================================
# 2. АУГМЕНТАЦИИ И ДАТАСЕТ
# ==========================================
train_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.HorizontalFlip(p=0.5),
    A.VerticalFlip(p=0.5),
    A.RandomRotate90(p=0.5),
    A.ShiftScaleRotate(
        shift_limit=0.15,
        scale_limit=0.15,
        rotate_limit=45,
        border_mode=cv2.BORDER_REFLECT_101,
        p=0.5),
    A.OneOf([
        A.ColorJitter(
            brightness=0.2,
            contrast=0.2,
            saturation=0.2,
            hue=0.05,
            p=1.0),
        A.RandomGamma(gamma_limit=(80, 120), p=1.0), 
        ],
        p=0.5),
    A.OneOf([
        A.GaussianBlur(blur_limit=(3, 5), p=1.0),
        A.GaussNoise(p=1.0),
        ],
        p=0.2),
    A.CoarseDropout(
        num_holes_range=(2, 6),
        hole_height_range=(8, 16),
        hole_width_range=(8, 16),
        fill=0,
        fill_mask=0,
        p=0.3
    ),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    ToTensorV2(),
])

val_transform = A.Compose([
    A.Resize(IMG_SIZE, IMG_SIZE),
    A.Normalize(mean=(0.485, 0.456, 0.406), std=(0.229, 0.224, 0.225)),
    ToTensorV2(),
])

class SegDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df.reset_index(drop=True)
        self.transform = transform

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        img_path = self.df.loc[idx, 'image_path']
        mask_path = self.df.loc[idx, 'mask_path']

        image = cv2.imread(str(img_path))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        
        mask = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)
        mask = (mask > 0).astype(np.float32)

        if self.transform:
            augmented = self.transform(image=image, mask=mask)
            image = augmented['image']
            mask = augmented['mask']
            
        return image, mask.unsqueeze(0)
# Out:
# /usr/local/lib/python3.12/dist-packages/albumentations/core/validation.py:114: UserWarning: ShiftScaleRotate is a special case of Affine transform. Please use Affine transform instead.
#   original_init(self, **validated_kwargs)

# %%
# ==========================================
# 3. ПОДГОТОВКА ДАННЫХ И СТРАТИФИКАЦИЯ
# ==========================================
def prepare_dataframe():
    """Собирает пути и считает площадь маски для стратификации объектов по размеру"""
    print("Подготовка датафрейма и расчет площадей масок...")
    data = []
    for mask_path in sorted(MASKS_DIR.glob("*.png")):
        img_path = IMAGES_DIR / (mask_path.stem + ".jpg")
        if img_path.exists():
            mask_preview = cv2.imread(str(mask_path), cv2.IMREAD_GRAYSCALE)
            area = np.sum(mask_preview > 0)
            data.append({"image_path": str(img_path), "mask_path": str(mask_path), "area": area})
    
    df = pd.DataFrame(data)
    df['area_bin'] = pd.qcut(df['area'], q=5, labels=False)
    print(f"Найдено {len(df)} изображений.")
    return df

# %%
# ==========================================
# 4. МЕТРИКИ И ФУНКЦИИ ОБУЧЕНИЯ (AMP)
# ==========================================
def dice_coef(y_pred, y_true, smooth=1e-6):
    y_pred = (torch.sigmoid(y_pred) > 0.5).float()
    intersection = (y_pred * y_true).sum(dim=(2, 3))
    union = y_pred.sum(dim=(2, 3)) + y_true.sum(dim=(2, 3))
    dice = (2. * intersection + smooth) / (union + smooth)
    return dice.mean().item()

def train_one_fold(model, train_loader, val_loader, optimizer, scheduler, criterion, fold, conf_name, epochs=EPOCHS):
    scaler = torch.amp.GradScaler('cuda')
    best_dice = 0.0
    best_epoch = 0
    history = {'train_loss': [], 'val_loss': [], 'val_dice': []}
    
    save_path = SAVE_DIR / f"{conf_name}_fold{fold}.pth"

    for epoch in range(1, epochs + 1):
        start_time = time.time()
        
        # ================= TRAIN =================
        model.train()
        train_loss = 0.0
        
        for images, masks in train_loader:
            images, masks = images.to(DEVICE), masks.to(DEVICE)
            optimizer.zero_grad(set_to_none=True)
            
            with torch.amp.autocast('cuda'):
                logits = model(images)
                loss = criterion(logits, masks)
            
            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()
            
            train_loss += loss.item()
            scheduler.step() 
            
        train_loss /= len(train_loader)

        # VALIDATION
        model.eval()
        val_loss, val_dice = 0.0, 0.0
        with torch.no_grad():
            for images, masks in val_loader:
                images, masks = images.to(DEVICE), masks.to(DEVICE)
                
                with torch.amp.autocast('cuda'):
                    logits = model(images)
                    loss = criterion(logits, masks)
                    
                val_loss += loss.item()
                val_dice += dice_coef(logits, masks)
                
        val_loss /= len(val_loader)
        val_dice /= len(val_loader)

        # ЛОГИРОВАНИЕ
        history['train_loss'].append(train_loss)
        history['val_loss'].append(val_loss)
        history['val_dice'].append(val_dice)
        
        epoch_time = time.time() - start_time

        if val_dice > best_dice:
            best_dice = val_dice
            best_epoch = epoch
            torch.save(model.state_dict(), save_path)
            print(f"   Epoch {epoch:02d}/{EPOCHS} [{epoch_time:.0f}s] | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Dice: {val_dice:.4f} -> Новый лучший Val Dice")
        else:
            print(f"   Epoch {epoch:02d}/{EPOCHS} [{epoch_time:.0f}s] | Train Loss: {train_loss:.4f} | Val Loss: {val_loss:.4f} | Val Dice: {val_dice:.4f}")
            
    print(f"✅ Fold {fold} завершен. Лучший Dice: {best_dice:.4f} на эпохе {best_epoch}. Сохранено: {save_path.name}")
    return history, best_dice, best_epoch

def plot_history(histories, conf_name):
    plt.figure(figsize=(15, 5))
    
    plt.subplot(1, 2, 1)
    for i, hist in enumerate(histories):
        plt.plot(hist['train_loss'], label=f'Train Fold {i+1}', linestyle='--')
        plt.plot(hist['val_loss'], label=f'Val Fold {i+1}')
    plt.title(f"{conf_name}: Loss")
    plt.legend(fontsize=8)
    
    plt.subplot(1, 2, 2)
    for i, hist in enumerate(histories):
        plt.plot(hist['val_dice'], label=f'Dice Fold {i+1}')
    plt.title(f"{conf_name}: Validation Dice")
    plt.legend(fontsize=8)
    
    plt.show()

# %%
# ==========================================
# 5. ГЛАВНЫЙ ЦИКЛ K-FOLD ДЛЯ ОДНОЙ КОНФИГУРАЦИИ
# ==========================================
def run_experiment(df, conf_name, arch, encoder, lr, weight_decay, epochs=EPOCHS):
    print(f"\n{'='*50}\n🚀 ЗАПУСК: {conf_name}\nАрхитектура: {arch} | Энкодер: {encoder}")
    print(f"Параметры: LR={lr}, Weight Decay={weight_decay}\n{'='*50}")
    
    skf = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=SEED)
    
    criterion = smp.losses.DiceLoss(mode='binary', from_logits=True)
    focal = smp.losses.FocalLoss(mode='binary')
    combo_loss = lambda y_pred, y_true: 0.5 * criterion(y_pred, y_true) + 0.5 * focal(y_pred, y_true)

    histories = []
    best_dices = []
    
    for fold, (train_idx, val_idx) in enumerate(skf.split(df, df['area_bin']), 1):
        print(f"\n--- Обучение Fold {fold}/{N_SPLITS} ---")
        
        train_df = df.iloc[train_idx]
        val_df = df.iloc[val_idx]
        
        train_loader = DataLoader(SegDataset(train_df, train_transform), batch_size=BATCH_SIZE, shuffle=True, num_workers=0, pin_memory=True, drop_last=True)
        val_loader = DataLoader(SegDataset(val_df, val_transform), batch_size=BATCH_SIZE, shuffle=False, num_workers=0, pin_memory=True)
        
        if arch == "UnetPlusPlus":
            model = smp.UnetPlusPlus(encoder_name=encoder, encoder_weights="imagenet", in_channels=3, classes=1)
        elif arch == "MAnet":
            model = smp.MAnet(encoder_name=encoder, encoder_weights="imagenet", in_channels=3, classes=1)
        elif arch == "DeepLabV3Plus":
            model = smp.DeepLabV3Plus(encoder_name=encoder, encoder_weights="imagenet", in_channels=3, classes=1)
            
        model.to(DEVICE)
        
        optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
        steps_per_epoch = len(train_loader)
        scheduler = torch.optim.lr_scheduler.OneCycleLR(
            optimizer,
            max_lr=lr,
            epochs=epochs,
            steps_per_epoch=steps_per_epoch,
            pct_start=0.1,
            div_factor=25.0,
            final_div_factor=1000.0
        )
        
        history, b_dice, b_epoch = train_one_fold(model, train_loader, val_loader, optimizer, scheduler, combo_loss, fold, conf_name)
        
        histories.append(history)
        best_dices.append(b_dice)
        
        del model, optimizer, scheduler, train_loader, val_loader
        gc.collect()
        torch.cuda.empty_cache()
        
    print(f"\n🏆 Итоги {conf_name}: Средний Dice по всем фолдам: {np.mean(best_dices):.4f}")
    plot_history(histories, conf_name)

# %%
# ==========================================
# 6. ЗАПУСК КОНФИГУРАЦИИ 3
# ==========================================
df = prepare_dataframe()

# Конфигурация 3: DeepLabV3+ convnext_small
run_experiment(
        df, conf_name="conf3_deeplab_convnext", arch="DeepLabV3Plus", encoder="tu-convnext_small",
        lr=4e-4, weight_decay=1e-2
    )
# Out:
# Подготовка датафрейма и расчет площадей масок...
# Найдено 2000 изображений.
#
# ==================================================
# 🚀 ЗАПУСК: conf3_deeplab_convnext
# Архитектура: DeepLabV3Plus | Энкодер: tu-convnext_small
# Параметры: LR=0.0004, Weight Decay=0.01
# ==================================================
#
# --- Обучение Fold 1/5 ---
#    Epoch 01/80 [65s] | Train Loss: 0.4284 | Val Loss: 0.3738 | Val Dice: 0.6868 -> Новый лучший Val Dice
#    Epoch 02/80 [59s] | Train Loss: 0.3257 | Val Loss: 0.2747 | Val Dice: 0.8020 -> Новый лучший Val Dice
#    Epoch 03/80 [60s] | Train Loss: 0.2437 | Val Loss: 0.2021 | Val Dice: 0.8408 -> Новый лучший Val Dice
#    Epoch 04/80 [63s] | Train Loss: 0.1842 | Val Loss: 0.1678 | Val Dice: 0.8201
#    Epoch 05/80 [60s] | Train Loss: 0.1502 | Val Loss: 0.1503 | Val Dice: 0.7904
#    Epoch 06/80 [60s] | Train Loss: 0.1278 | Val Loss: 0.1768 | Val Dice: 0.7891
#    Epoch 07/80 [60s] | Train Loss: 0.1175 | Val Loss: 0.1018 | Val Dice: 0.8495 -> Новый лучший Val Dice
#    Epoch 08/80 [62s] | Train Loss: 0.1106 | Val Loss: 0.0966 | Val Dice: 0.8432
#    Epoch 09/80 [61s] | Train Loss: 0.0986 | Val Loss: 0.0933 | Val Dice: 0.8530 -> Новый лучший Val Dice
#    Epoch 10/80 [63s] | Train Loss: 0.0934 | Val Loss: 0.0843 | Val Dice: 0.8594 -> Новый лучший Val Dice
#    Epoch 11/80 [61s] | Train Loss: 0.0863 | Val Loss: 0.0839 | Val Dice: 0.8607 -> Новый лучший Val Dice
#    Epoch 12/80 [60s] | Train Loss: 0.0794 | Val Loss: 0.0834 | Val Dice: 0.8552
#    Epoch 13/80 [70s] | Train Loss: 0.0841 | Val Loss: 0.0823 | Val Dice: 0.8599
#    Epoch 14/80 [107s] | Train Loss: 0.0777 | Val Loss: 0.1163 | Val Dice: 0.8221
#    Epoch 15/80 [105s] | Train Loss: 0.0778 | Val Loss: 0.0853 | Val Dice: 0.8586
#    Epoch 16/80 [82s] | Train Loss: 0.0744 | Val Loss: 0.0760 | Val Dice: 0.8654 -> Новый лучший Val Dice
#    Epoch 17/80 [60s] | Train Loss: 0.0660 | Val Loss: 0.0702 | Val Dice: 0.8807 -> Новый лучший Val Dice
#    Epoch 18/80 [64s] | Train Loss: 0.0760 | Val Loss: 0.0802 | Val Dice: 0.8603
#    Epoch 19/80 [69s] | Train Loss: 0.0758 | Val Loss: 0.0780 | Val Dice: 0.8679
#    Epoch 20/80 [66s] | Train Loss: 0.0655 | Val Loss: 0.0731 | Val Dice: 0.8737
#    Epoch 21/80 [59s] | Train Loss: 0.0631 | Val Loss: 0.0746 | Val Dice: 0.8765
#    Epoch 22/80 [59s] | Train Loss: 0.0601 | Val Loss: 0.0765 | Val Dice: 0.8699
#    Epoch 23/80 [60s] | Train Loss: 0.0596 | Val Loss: 0.0732 | Val Dice: 0.8678
#    Epoch 24/80 [60s] | Train Loss: 0.0605 | Val Loss: 0.0651 | Val Dice: 0.8821 -> Новый лучший Val Dice
#    Epoch 25/80 [60s] | Train Loss: 0.0574 | Val Loss: 0.0648 | Val Dice: 0.8848 -> Новый лучший Val Dice
#    Epoch 26/80 [66s] | Train Loss: 0.0540 | Val Loss: 0.0698 | Val Dice: 0.8760
#    Epoch 27/80 [69s] | Train Loss: 0.0580 | Val Loss: 0.0685 | Val Dice: 0.8817
#    Epoch 28/80 [64s] | Train Loss: 0.0565 | Val Loss: 0.0743 | Val Dice: 0.8749
#    Epoch 29/80 [64s] | Train Loss: 0.0541 | Val Loss: 0.0691 | Val Dice: 0.8723
#    Epoch 30/80 [70s] | Train Loss: 0.0535 | Val Loss: 0.0630 | Val Dice: 0.8856 -> Новый лучший Val Dice
#    Epoch 31/80 [61s] | Train Loss: 0.0499 | Val Loss: 0.0702 | Val Dice: 0.8843
#    Epoch 32/80 [60s] | Train Loss: 0.0541 | Val Loss: 0.0761 | Val Dice: 0.8738
#    Epoch 33/80 [59s] | Train Loss: 0.0490 | Val Loss: 0.0633 | Val Dice: 0.8829
#    Epoch 34/80 [60s] | Train Loss: 0.0472 | Val Loss: 0.0612 | Val Dice: 0.8888 -> Новый лучший Val Dice
#    Epoch 35/80 [60s] | Train Loss: 0.0445 | Val Loss: 0.0613 | Val Dice: 0.8956 -> Новый лучший Val Dice
#    Epoch 36/80 [60s] | Train Loss: 0.0467 | Val Loss: 0.0635 | Val Dice: 0.8909
#    Epoch 37/80 [59s] | Train Loss: 0.0436 | Val Loss: 0.0646 | Val Dice: 0.8966 -> Новый лучший Val Dice
#    Epoch 38/80 [59s] | Train Loss: 0.0440 | Val Loss: 0.0682 | Val Dice: 0.8848
#    Epoch 39/80 [60s] | Train Loss: 0.0430 | Val Loss: 0.0661 | Val Dice: 0.8920
#    Epoch 40/80 [60s] | Train Loss: 0.0418 | Val Loss: 0.0641 | Val Dice: 0.8927
#    Epoch 41/80 [69s] | Train Loss: 0.0409 | Val Loss: 0.0676 | Val Dice: 0.8886
#    Epoch 42/80 [70s] | Train Loss: 0.0395 | Val Loss: 0.0622 | Val Dice: 0.8977 -> Новый лучший Val Dice
#    Epoch 43/80 [70s] | Train Loss: 0.0388 | Val Loss: 0.0627 | Val Dice: 0.8954
#    Epoch 44/80 [64s] | Train Loss: 0.0423 | Val Loss: 0.0691 | Val Dice: 0.8828
#    Epoch 45/80 [59s] | Train Loss: 0.0410 | Val Loss: 0.0664 | Val Dice: 0.8916
#    Epoch 46/80 [61s] | Train Loss: 0.0379 | Val Loss: 0.0678 | Val Dice: 0.8858
#    Epoch 47/80 [60s] | Train Loss: 0.0370 | Val Loss: 0.0644 | Val Dice: 0.8893
#    Epoch 48/80 [60s] | Train Loss: 0.0367 | Val Loss: 0.0649 | Val Dice: 0.8933
#    Epoch 49/80 [64s] | Train Loss: 0.0369 | Val Loss: 0.0616 | Val Dice: 0.8991 -> Новый лучший Val Dice
#    Epoch 50/80 [66s] | Train Loss: 0.0360 | Val Loss: 0.0734 | Val Dice: 0.8811
#    Epoch 51/80 [63s] | Train Loss: 0.0356 | Val Loss: 0.0647 | Val Dice: 0.8940
#    Epoch 52/80 [62s] | Train Loss: 0.0344 | Val Loss: 0.0615 | Val Dice: 0.8979
#    Epoch 53/80 [59s] | Train Loss: 0.0339 | Val Loss: 0.0669 | Val Dice: 0.8913
#    Epoch 54/80 [60s] | Train Loss: 0.0328 | Val Loss: 0.0628 | Val Dice: 0.8977
#    Epoch 55/80 [71s] | Train Loss: 0.0324 | Val Loss: 0.0681 | Val Dice: 0.8905
#    Epoch 56/80 [59s] | Train Loss: 0.0321 | Val Loss: 0.0623 | Val Dice: 0.8934
#    Epoch 57/80 [59s] | Train Loss: 0.0310 | Val Loss: 0.0631 | Val Dice: 0.8948
#    Epoch 58/80 [58s] | Train Loss: 0.0307 | Val Loss: 0.0695 | Val Dice: 0.8890
#    Epoch 59/80 [64s] | Train Loss: 0.0308 | Val Loss: 0.0639 | Val Dice: 0.8965
#    Epoch 60/80 [68s] | Train Loss: 0.0302 | Val Loss: 0.0606 | Val Dice: 0.9005 -> Новый лучший Val Dice
#    Epoch 61/80 [68s] | Train Loss: 0.0299 | Val Loss: 0.0615 | Val Dice: 0.8988
#    Epoch 62/80 [72s] | Train Loss: 0.0296 | Val Loss: 0.0629 | Val Dice: 0.8998
#    Epoch 63/80 [82s] | Train Loss: 0.0292 | Val Loss: 0.0652 | Val Dice: 0.8979
#    Epoch 64/80 [67s] | Train Loss: 0.0292 | Val Loss: 0.0627 | Val Dice: 0.9024 -> Новый лучший Val Dice
#    Epoch 65/80 [60s] | Train Loss: 0.0287 | Val Loss: 0.0619 | Val Dice: 0.9014
#    Epoch 66/80 [63s] | Train Loss: 0.0288 | Val Loss: 0.0634 | Val Dice: 0.9000
#    Epoch 67/80 [61s] | Train Loss: 0.0285 | Val Loss: 0.0630 | Val Dice: 0.8997
#    Epoch 68/80 [61s] | Train Loss: 0.0278 | Val Loss: 0.0620 | Val Dice: 0.9010
#    Epoch 69/80 [62s] | Train Loss: 0.0279 | Val Loss: 0.0635 | Val Dice: 0.8995
#    Epoch 70/80 [61s] | Train Loss: 0.0278 | Val Loss: 0.0634 | Val Dice: 0.9003
#    Epoch 71/80 [64s] | Train Loss: 0.0272 | Val Loss: 0.0635 | Val Dice: 0.9001
#    Epoch 72/80 [63s] | Train Loss: 0.0280 | Val Loss: 0.0636 | Val Dice: 0.9002
#    Epoch 73/80 [70s] | Train Loss: 0.0270 | Val Loss: 0.0637 | Val Dice: 0.9002
#    Epoch 74/80 [72s] | Train Loss: 0.0275 | Val Loss: 0.0635 | Val Dice: 0.9006
#    Epoch 75/80 [76s] | Train Loss: 0.0276 | Val Loss: 0.0636 | Val Dice: 0.9001
#    Epoch 76/80 [80s] | Train Loss: 0.0271 | Val Loss: 0.0632 | Val Dice: 0.9007
#    Epoch 77/80 [83s] | Train Loss: 0.0271 | Val Loss: 0.0636 | Val Dice: 0.9001
#    Epoch 78/80 [65s] | Train Loss: 0.0273 | Val Loss: 0.0634 | Val Dice: 0.9003
#    Epoch 79/80 [64s] | Train Loss: 0.0271 | Val Loss: 0.0635 | Val Dice: 0.9001
#    Epoch 80/80 [65s] | Train Loss: 0.0277 | Val Loss: 0.0634 | Val Dice: 0.9001
# ✅ Fold 1 завершен. Лучший Dice: 0.9024 на эпохе 64. Сохранено: conf3_deeplab_convnext_fold1.pth
#
# --- Обучение Fold 2/5 ---
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
#    Epoch 01/80 [67s] | Train Loss: 0.4184 | Val Loss: 0.3822 | Val Dice: 0.6030 -> Новый лучший Val Dice
#    Epoch 02/80 [69s] | Train Loss: 0.3192 | Val Loss: 0.3011 | Val Dice: 0.7376 -> Новый лучший Val Dice
#    Epoch 03/80 [69s] | Train Loss: 0.2346 | Val Loss: 0.2115 | Val Dice: 0.7909 -> Новый лучший Val Dice
#    Epoch 04/80 [71s] | Train Loss: 0.1688 | Val Loss: 0.1453 | Val Dice: 0.8199 -> Новый лучший Val Dice
#    Epoch 05/80 [70s] | Train Loss: 0.1388 | Val Loss: 0.1233 | Val Dice: 0.8284 -> Новый лучший Val Dice
#    Epoch 06/80 [71s] | Train Loss: 0.1176 | Val Loss: 0.1088 | Val Dice: 0.8294 -> Новый лучший Val Dice
#    Epoch 07/80 [69s] | Train Loss: 0.1213 | Val Loss: 0.1194 | Val Dice: 0.8116
#    Epoch 08/80 [72s] | Train Loss: 0.1181 | Val Loss: 0.0993 | Val Dice: 0.8420 -> Новый лучший Val Dice
#    Epoch 09/80 [65s] | Train Loss: 0.1030 | Val Loss: 0.1013 | Val Dice: 0.8321
#    Epoch 10/80 [64s] | Train Loss: 0.0950 | Val Loss: 0.0933 | Val Dice: 0.8559 -> Новый лучший Val Dice
#    Epoch 11/80 [63s] | Train Loss: 0.0906 | Val Loss: 0.0865 | Val Dice: 0.8563 -> Новый лучший Val Dice
#    Epoch 12/80 [62s] | Train Loss: 0.0798 | Val Loss: 0.0861 | Val Dice: 0.8556
#    Epoch 13/80 [62s] | Train Loss: 0.0766 | Val Loss: 0.0895 | Val Dice: 0.8503
#    Epoch 14/80 [66s] | Train Loss: 0.0781 | Val Loss: 0.0753 | Val Dice: 0.8675 -> Новый лучший Val Dice
#    Epoch 15/80 [68s] | Train Loss: 0.0719 | Val Loss: 0.0805 | Val Dice: 0.8647
#    Epoch 16/80 [81s] | Train Loss: 0.0756 | Val Loss: 0.0767 | Val Dice: 0.8723 -> Новый лучший Val Dice
#    Epoch 17/80 [69s] | Train Loss: 0.0772 | Val Loss: 0.0730 | Val Dice: 0.8693
#    Epoch 18/80 [64s] | Train Loss: 0.0722 | Val Loss: 0.0828 | Val Dice: 0.8539
#    Epoch 19/80 [62s] | Train Loss: 0.0679 | Val Loss: 0.0704 | Val Dice: 0.8807 -> Новый лучший Val Dice
#    Epoch 20/80 [69s] | Train Loss: 0.0627 | Val Loss: 0.0716 | Val Dice: 0.8790
#    Epoch 21/80 [63s] | Train Loss: 0.0656 | Val Loss: 0.0708 | Val Dice: 0.8765
#    Epoch 22/80 [62s] | Train Loss: 0.0660 | Val Loss: 0.0723 | Val Dice: 0.8752
#    Epoch 23/80 [61s] | Train Loss: 0.0616 | Val Loss: 0.0715 | Val Dice: 0.8715
#    Epoch 24/80 [60s] | Train Loss: 0.0577 | Val Loss: 0.0738 | Val Dice: 0.8802
#    Epoch 25/80 [63s] | Train Loss: 0.0581 | Val Loss: 0.0685 | Val Dice: 0.8848 -> Новый лучший Val Dice
#    Epoch 26/80 [90s] | Train Loss: 0.0599 | Val Loss: 0.0700 | Val Dice: 0.8795
#    Epoch 27/80 [86s] | Train Loss: 0.0616 | Val Loss: 0.0751 | Val Dice: 0.8730
#    Epoch 28/80 [70s] | Train Loss: 0.0507 | Val Loss: 0.0705 | Val Dice: 0.8814
#    Epoch 29/80 [69s] | Train Loss: 0.0546 | Val Loss: 0.0755 | Val Dice: 0.8764
#    Epoch 30/80 [61s] | Train Loss: 0.0625 | Val Loss: 0.0690 | Val Dice: 0.8801
#    Epoch 31/80 [66s] | Train Loss: 0.0534 | Val Loss: 0.0701 | Val Dice: 0.8762
#    Epoch 32/80 [62s] | Train Loss: 0.0568 | Val Loss: 0.0669 | Val Dice: 0.8871 -> Новый лучший Val Dice
#    Epoch 33/80 [71s] | Train Loss: 0.0554 | Val Loss: 0.0632 | Val Dice: 0.8892 -> Новый лучший Val Dice
#    Epoch 34/80 [62s] | Train Loss: 0.0513 | Val Loss: 0.0656 | Val Dice: 0.8901 -> Новый лучший Val Dice
#    Epoch 35/80 [60s] | Train Loss: 0.0525 | Val Loss: 0.0744 | Val Dice: 0.8816
#    Epoch 36/80 [71s] | Train Loss: 0.0513 | Val Loss: 0.0639 | Val Dice: 0.8943 -> Новый лучший Val Dice
#    Epoch 37/80 [87s] | Train Loss: 0.0463 | Val Loss: 0.0685 | Val Dice: 0.8921
#    Epoch 38/80 [72s] | Train Loss: 0.0502 | Val Loss: 0.0691 | Val Dice: 0.8845
#    Epoch 39/80 [87s] | Train Loss: 0.0475 | Val Loss: 0.0620 | Val Dice: 0.8923
#    Epoch 40/80 [63s] | Train Loss: 0.0479 | Val Loss: 0.0665 | Val Dice: 0.8903
#    Epoch 41/80 [81s] | Train Loss: 0.0459 | Val Loss: 0.0622 | Val Dice: 0.8942
#    Epoch 42/80 [70s] | Train Loss: 0.0443 | Val Loss: 0.0610 | Val Dice: 0.8962 -> Новый лучший Val Dice
#    Epoch 43/80 [61s] | Train Loss: 0.0438 | Val Loss: 0.0619 | Val Dice: 0.8925
#    Epoch 44/80 [64s] | Train Loss: 0.0407 | Val Loss: 0.0598 | Val Dice: 0.8960
#    Epoch 45/80 [64s] | Train Loss: 0.0433 | Val Loss: 0.0642 | Val Dice: 0.8853
#    Epoch 46/80 [61s] | Train Loss: 0.0409 | Val Loss: 0.0632 | Val Dice: 0.8945
#    Epoch 47/80 [67s] | Train Loss: 0.0384 | Val Loss: 0.0641 | Val Dice: 0.8907
#    Epoch 48/80 [66s] | Train Loss: 0.0377 | Val Loss: 0.0609 | Val Dice: 0.8976 -> Новый лучший Val Dice
#    Epoch 49/80 [100s] | Train Loss: 0.0366 | Val Loss: 0.0598 | Val Dice: 0.8984 -> Новый лучший Val Dice
#    Epoch 50/80 [96s] | Train Loss: 0.0369 | Val Loss: 0.0616 | Val Dice: 0.8964
#    Epoch 51/80 [90s] | Train Loss: 0.0366 | Val Loss: 0.0633 | Val Dice: 0.8926
#    Epoch 52/80 [82s] | Train Loss: 0.0352 | Val Loss: 0.0602 | Val Dice: 0.8936
#    Epoch 53/80 [86s] | Train Loss: 0.0346 | Val Loss: 0.0613 | Val Dice: 0.8968
#    Epoch 54/80 [71s] | Train Loss: 0.0356 | Val Loss: 0.0609 | Val Dice: 0.8953
#    Epoch 55/80 [74s] | Train Loss: 0.0330 | Val Loss: 0.0611 | Val Dice: 0.8977
#    Epoch 56/80 [80s] | Train Loss: 0.0331 | Val Loss: 0.0612 | Val Dice: 0.8951
#    Epoch 57/80 [82s] | Train Loss: 0.0336 | Val Loss: 0.0603 | Val Dice: 0.8988 -> Новый лучший Val Dice
#    Epoch 58/80 [76s] | Train Loss: 0.0330 | Val Loss: 0.0596 | Val Dice: 0.9019 -> Новый лучший Val Dice
#    Epoch 59/80 [87s] | Train Loss: 0.0319 | Val Loss: 0.0589 | Val Dice: 0.9034 -> Новый лучший Val Dice
#    Epoch 60/80 [92s] | Train Loss: 0.0315 | Val Loss: 0.0581 | Val Dice: 0.9050 -> Новый лучший Val Dice
#    Epoch 61/80 [124s] | Train Loss: 0.0321 | Val Loss: 0.0598 | Val Dice: 0.9028
#    Epoch 62/80 [94s] | Train Loss: 0.0313 | Val Loss: 0.0595 | Val Dice: 0.9023
#    Epoch 63/80 [78s] | Train Loss: 0.0310 | Val Loss: 0.0594 | Val Dice: 0.9003
#    Epoch 64/80 [86s] | Train Loss: 0.0305 | Val Loss: 0.0589 | Val Dice: 0.9044
#    Epoch 65/80 [88s] | Train Loss: 0.0303 | Val Loss: 0.0580 | Val Dice: 0.9050 -> Новый лучший Val Dice
#    Epoch 66/80 [84s] | Train Loss: 0.0302 | Val Loss: 0.0582 | Val Dice: 0.9040
#    Epoch 67/80 [79s] | Train Loss: 0.0296 | Val Loss: 0.0584 | Val Dice: 0.9023
#    Epoch 68/80 [83s] | Train Loss: 0.0298 | Val Loss: 0.0585 | Val Dice: 0.9033
#    Epoch 69/80 [78s] | Train Loss: 0.0298 | Val Loss: 0.0580 | Val Dice: 0.9045
#    Epoch 70/80 [91s] | Train Loss: 0.0294 | Val Loss: 0.0580 | Val Dice: 0.9038
#    Epoch 71/80 [84s] | Train Loss: 0.0296 | Val Loss: 0.0584 | Val Dice: 0.9041
#    Epoch 72/80 [86s] | Train Loss: 0.0300 | Val Loss: 0.0579 | Val Dice: 0.9047
#    Epoch 73/80 [79s] | Train Loss: 0.0296 | Val Loss: 0.0580 | Val Dice: 0.9041
#    Epoch 74/80 [82s] | Train Loss: 0.0293 | Val Loss: 0.0577 | Val Dice: 0.9043
#    Epoch 75/80 [73s] | Train Loss: 0.0294 | Val Loss: 0.0579 | Val Dice: 0.9046
#    Epoch 76/80 [74s] | Train Loss: 0.0288 | Val Loss: 0.0579 | Val Dice: 0.9045
#    Epoch 77/80 [77s] | Train Loss: 0.0289 | Val Loss: 0.0581 | Val Dice: 0.9043
#    Epoch 78/80 [69s] | Train Loss: 0.0288 | Val Loss: 0.0581 | Val Dice: 0.9045
#    Epoch 79/80 [66s] | Train Loss: 0.0288 | Val Loss: 0.0580 | Val Dice: 0.9047
#    Epoch 80/80 [67s] | Train Loss: 0.0288 | Val Loss: 0.0579 | Val Dice: 0.9046
# ✅ Fold 2 завершен. Лучший Dice: 0.9050 на эпохе 65. Сохранено: conf3_deeplab_convnext_fold2.pth
#
# --- Обучение Fold 3/5 ---
#    Epoch 01/80 [68s] | Train Loss: 0.4267 | Val Loss: 0.3920 | Val Dice: 0.6222 -> Новый лучший Val Dice
#    Epoch 02/80 [65s] | Train Loss: 0.3263 | Val Loss: 0.2760 | Val Dice: 0.7835 -> Новый лучший Val Dice
#    Epoch 03/80 [64s] | Train Loss: 0.2438 | Val Loss: 0.2174 | Val Dice: 0.8063 -> Новый лучший Val Dice
#    Epoch 04/80 [65s] | Train Loss: 0.1854 | Val Loss: 0.1584 | Val Dice: 0.8324 -> Новый лучший Val Dice
#    Epoch 05/80 [64s] | Train Loss: 0.1418 | Val Loss: 0.1263 | Val Dice: 0.8197
#    Epoch 06/80 [66s] | Train Loss: 0.1357 | Val Loss: 0.1480 | Val Dice: 0.8062
#    Epoch 07/80 [65s] | Train Loss: 0.1232 | Val Loss: 0.1057 | Val Dice: 0.8156
#    Epoch 08/80 [63s] | Train Loss: 0.1121 | Val Loss: 0.0875 | Val Dice: 0.8531 -> Новый лучший Val Dice
#    Epoch 09/80 [75s] | Train Loss: 0.0970 | Val Loss: 0.0998 | Val Dice: 0.8429
#    Epoch 10/80 [66s] | Train Loss: 0.0914 | Val Loss: 0.0759 | Val Dice: 0.8663 -> Новый лучший Val Dice
#    Epoch 11/80 [82s] | Train Loss: 0.0851 | Val Loss: 0.0754 | Val Dice: 0.8624
#    Epoch 12/80 [76s] | Train Loss: 0.0860 | Val Loss: 0.0737 | Val Dice: 0.8531
#    Epoch 13/80 [74s] | Train Loss: 0.0826 | Val Loss: 0.0750 | Val Dice: 0.8581
#    Epoch 14/80 [65s] | Train Loss: 0.0762 | Val Loss: 0.0727 | Val Dice: 0.8649
#    Epoch 15/80 [65s] | Train Loss: 0.0779 | Val Loss: 0.0814 | Val Dice: 0.8559
#    Epoch 16/80 [65s] | Train Loss: 0.0733 | Val Loss: 0.0642 | Val Dice: 0.8821 -> Новый лучший Val Dice
#    Epoch 17/80 [68s] | Train Loss: 0.0671 | Val Loss: 0.0691 | Val Dice: 0.8778
#    Epoch 18/80 [64s] | Train Loss: 0.0710 | Val Loss: 0.0660 | Val Dice: 0.8717
#    Epoch 19/80 [65s] | Train Loss: 0.0739 | Val Loss: 0.0753 | Val Dice: 0.8622
#    Epoch 20/80 [79s] | Train Loss: 0.0679 | Val Loss: 0.0624 | Val Dice: 0.8900 -> Новый лучший Val Dice
#    Epoch 21/80 [84s] | Train Loss: 0.0619 | Val Loss: 0.0748 | Val Dice: 0.8549
#    Epoch 22/80 [79s] | Train Loss: 0.0793 | Val Loss: 0.0727 | Val Dice: 0.8708
#    Epoch 23/80 [68s] | Train Loss: 0.0690 | Val Loss: 0.0658 | Val Dice: 0.8779
#    Epoch 24/80 [61s] | Train Loss: 0.0629 | Val Loss: 0.0674 | Val Dice: 0.8794
#    Epoch 25/80 [63s] | Train Loss: 0.0648 | Val Loss: 0.0818 | Val Dice: 0.8592
#    Epoch 26/80 [59s] | Train Loss: 0.0674 | Val Loss: 0.0607 | Val Dice: 0.8875
#    Epoch 27/80 [60s] | Train Loss: 0.0591 | Val Loss: 0.0637 | Val Dice: 0.8802
#    Epoch 28/80 [61s] | Train Loss: 0.0568 | Val Loss: 0.0610 | Val Dice: 0.8805
#    Epoch 29/80 [60s] | Train Loss: 0.0519 | Val Loss: 0.0598 | Val Dice: 0.8921 -> Новый лучший Val Dice
#    Epoch 30/80 [61s] | Train Loss: 0.0541 | Val Loss: 0.0639 | Val Dice: 0.8825
#    Epoch 31/80 [68s] | Train Loss: 0.0546 | Val Loss: 0.0605 | Val Dice: 0.8835
#    Epoch 32/80 [62s] | Train Loss: 0.0539 | Val Loss: 0.0636 | Val Dice: 0.8823
#    Epoch 33/80 [59s] | Train Loss: 0.0561 | Val Loss: 0.0634 | Val Dice: 0.8825
#    Epoch 34/80 [84s] | Train Loss: 0.0507 | Val Loss: 0.0600 | Val Dice: 0.8896
#    Epoch 35/80 [71s] | Train Loss: 0.0464 | Val Loss: 0.0629 | Val Dice: 0.8837
#    Epoch 36/80 [61s] | Train Loss: 0.0496 | Val Loss: 0.0600 | Val Dice: 0.8934 -> Новый лучший Val Dice
#    Epoch 37/80 [70s] | Train Loss: 0.0463 | Val Loss: 0.0592 | Val Dice: 0.8936 -> Новый лучший Val Dice
#    Epoch 38/80 [64s] | Train Loss: 0.0457 | Val Loss: 0.0578 | Val Dice: 0.8964 -> Новый лучший Val Dice
#    Epoch 39/80 [62s] | Train Loss: 0.0443 | Val Loss: 0.0592 | Val Dice: 0.8938
#    Epoch 40/80 [65s] | Train Loss: 0.0432 | Val Loss: 0.0580 | Val Dice: 0.8860
#    Epoch 41/80 [66s] | Train Loss: 0.0413 | Val Loss: 0.0562 | Val Dice: 0.8937
#    Epoch 42/80 [66s] | Train Loss: 0.0422 | Val Loss: 0.0548 | Val Dice: 0.9006 -> Новый лучший Val Dice
#    Epoch 43/80 [62s] | Train Loss: 0.0427 | Val Loss: 0.0586 | Val Dice: 0.8882
#    Epoch 44/80 [66s] | Train Loss: 0.0412 | Val Loss: 0.0569 | Val Dice: 0.8957
#    Epoch 45/80 [77s] | Train Loss: 0.0411 | Val Loss: 0.0559 | Val Dice: 0.8970
#    Epoch 46/80 [87s] | Train Loss: 0.0390 | Val Loss: 0.0551 | Val Dice: 0.9045 -> Новый лучший Val Dice
#    Epoch 47/80 [120s] | Train Loss: 0.0384 | Val Loss: 0.0564 | Val Dice: 0.8967
#    Epoch 48/80 [109s] | Train Loss: 0.0379 | Val Loss: 0.0537 | Val Dice: 0.9019
#    Epoch 49/80 [83s] | Train Loss: 0.0367 | Val Loss: 0.0552 | Val Dice: 0.9010
#    Epoch 50/80 [72s] | Train Loss: 0.0371 | Val Loss: 0.0557 | Val Dice: 0.8993
#    Epoch 51/80 [85s] | Train Loss: 0.0349 | Val Loss: 0.0551 | Val Dice: 0.9044
#    Epoch 52/80 [75s] | Train Loss: 0.0347 | Val Loss: 0.0546 | Val Dice: 0.9046 -> Новый лучший Val Dice
#    Epoch 53/80 [70s] | Train Loss: 0.0335 | Val Loss: 0.0548 | Val Dice: 0.9047 -> Новый лучший Val Dice
#    Epoch 54/80 [72s] | Train Loss: 0.0332 | Val Loss: 0.0549 | Val Dice: 0.9012
#    Epoch 55/80 [70s] | Train Loss: 0.0332 | Val Loss: 0.0544 | Val Dice: 0.9039
#    Epoch 56/80 [133s] | Train Loss: 0.0333 | Val Loss: 0.0540 | Val Dice: 0.9058 -> Новый лучший Val Dice
#    Epoch 57/80 [155s] | Train Loss: 0.0323 | Val Loss: 0.0550 | Val Dice: 0.9038
#    Epoch 58/80 [66s] | Train Loss: 0.0321 | Val Loss: 0.0558 | Val Dice: 0.9033
#    Epoch 59/80 [82s] | Train Loss: 0.0333 | Val Loss: 0.0549 | Val Dice: 0.9057
#    Epoch 60/80 [76s] | Train Loss: 0.0312 | Val Loss: 0.0559 | Val Dice: 0.8969
#    Epoch 61/80 [69s] | Train Loss: 0.0316 | Val Loss: 0.0540 | Val Dice: 0.9054
#    Epoch 62/80 [65s] | Train Loss: 0.0309 | Val Loss: 0.0542 | Val Dice: 0.9042
#    Epoch 63/80 [64s] | Train Loss: 0.0308 | Val Loss: 0.0540 | Val Dice: 0.9055
#    Epoch 64/80 [69s] | Train Loss: 0.0297 | Val Loss: 0.0533 | Val Dice: 0.9075 -> Новый лучший Val Dice
#    Epoch 65/80 [65s] | Train Loss: 0.0300 | Val Loss: 0.0535 | Val Dice: 0.9065
#    Epoch 66/80 [63s] | Train Loss: 0.0295 | Val Loss: 0.0541 | Val Dice: 0.9066
#    Epoch 67/80 [69s] | Train Loss: 0.0293 | Val Loss: 0.0542 | Val Dice: 0.9054
#    Epoch 68/80 [63s] | Train Loss: 0.0298 | Val Loss: 0.0544 | Val Dice: 0.9046
#    Epoch 69/80 [63s] | Train Loss: 0.0289 | Val Loss: 0.0540 | Val Dice: 0.9066
#    Epoch 70/80 [72s] | Train Loss: 0.0287 | Val Loss: 0.0541 | Val Dice: 0.9051
#    Epoch 71/80 [68s] | Train Loss: 0.0286 | Val Loss: 0.0544 | Val Dice: 0.9055
#    Epoch 72/80 [64s] | Train Loss: 0.0290 | Val Loss: 0.0538 | Val Dice: 0.9078 -> Новый лучший Val Dice
#    Epoch 73/80 [64s] | Train Loss: 0.0290 | Val Loss: 0.0539 | Val Dice: 0.9068
#    Epoch 74/80 [73s] | Train Loss: 0.0287 | Val Loss: 0.0539 | Val Dice: 0.9070
#    Epoch 75/80 [68s] | Train Loss: 0.0287 | Val Loss: 0.0539 | Val Dice: 0.9067
#    Epoch 76/80 [64s] | Train Loss: 0.0282 | Val Loss: 0.0538 | Val Dice: 0.9069
#    Epoch 77/80 [62s] | Train Loss: 0.0287 | Val Loss: 0.0538 | Val Dice: 0.9063
#    Epoch 78/80 [62s] | Train Loss: 0.0285 | Val Loss: 0.0538 | Val Dice: 0.9068
#    Epoch 79/80 [64s] | Train Loss: 0.0288 | Val Loss: 0.0539 | Val Dice: 0.9068
#    Epoch 80/80 [62s] | Train Loss: 0.0281 | Val Loss: 0.0538 | Val Dice: 0.9069
# ✅ Fold 3 завершен. Лучший Dice: 0.9078 на эпохе 72. Сохранено: conf3_deeplab_convnext_fold3.pth
#
# --- Обучение Fold 4/5 ---
#    Epoch 01/80 [63s] | Train Loss: 0.3955 | Val Loss: 0.3519 | Val Dice: 0.6685 -> Новый лучший Val Dice
#    Epoch 02/80 [63s] | Train Loss: 0.3051 | Val Loss: 0.2589 | Val Dice: 0.7948 -> Новый лучший Val Dice
#    Epoch 03/80 [62s] | Train Loss: 0.2274 | Val Loss: 0.2000 | Val Dice: 0.8236 -> Новый лучший Val Dice
#    Epoch 04/80 [103s] | Train Loss: 0.1742 | Val Loss: 0.1771 | Val Dice: 0.7587
#    Epoch 05/80 [95s] | Train Loss: 0.1407 | Val Loss: 0.1450 | Val Dice: 0.8268 -> Новый лучший Val Dice
#    Epoch 06/80 [77s] | Train Loss: 0.1266 | Val Loss: 0.1227 | Val Dice: 0.8207
#    Epoch 07/80 [59s] | Train Loss: 0.1145 | Val Loss: 0.1059 | Val Dice: 0.8300 -> Новый лучший Val Dice
#    Epoch 08/80 [60s] | Train Loss: 0.1096 | Val Loss: 0.1009 | Val Dice: 0.8316 -> Новый лучший Val Dice
#    Epoch 09/80 [60s] | Train Loss: 0.1015 | Val Loss: 0.0883 | Val Dice: 0.8592 -> Новый лучший Val Dice
#    Epoch 10/80 [61s] | Train Loss: 0.0849 | Val Loss: 0.0891 | Val Dice: 0.8603 -> Новый лучший Val Dice
#    Epoch 11/80 [61s] | Train Loss: 0.0880 | Val Loss: 0.0861 | Val Dice: 0.8614 -> Новый лучший Val Dice
#    Epoch 12/80 [62s] | Train Loss: 0.0811 | Val Loss: 0.0875 | Val Dice: 0.8614 -> Новый лучший Val Dice
#    Epoch 13/80 [60s] | Train Loss: 0.0820 | Val Loss: 0.0871 | Val Dice: 0.8582
#    Epoch 14/80 [60s] | Train Loss: 0.0812 | Val Loss: 0.1004 | Val Dice: 0.8530
#    Epoch 15/80 [60s] | Train Loss: 0.0838 | Val Loss: 0.0817 | Val Dice: 0.8738 -> Новый лучший Val Dice
#    Epoch 16/80 [59s] | Train Loss: 0.0721 | Val Loss: 0.0811 | Val Dice: 0.8781 -> Новый лучший Val Dice
#    Epoch 17/80 [60s] | Train Loss: 0.0709 | Val Loss: 0.0824 | Val Dice: 0.8691
#    Epoch 18/80 [60s] | Train Loss: 0.0678 | Val Loss: 0.0742 | Val Dice: 0.8801 -> Новый лучший Val Dice
#    Epoch 19/80 [67s] | Train Loss: 0.0653 | Val Loss: 0.0802 | Val Dice: 0.8849 -> Новый лучший Val Dice
#    Epoch 20/80 [74s] | Train Loss: 0.0785 | Val Loss: 0.0892 | Val Dice: 0.8592
#    Epoch 21/80 [68s] | Train Loss: 0.0681 | Val Loss: 0.0787 | Val Dice: 0.8811
#    Epoch 22/80 [76s] | Train Loss: 0.0652 | Val Loss: 0.0825 | Val Dice: 0.8677
#    Epoch 23/80 [60s] | Train Loss: 0.0629 | Val Loss: 0.0713 | Val Dice: 0.8886 -> Новый лучший Val Dice
#    Epoch 24/80 [70s] | Train Loss: 0.0632 | Val Loss: 0.0831 | Val Dice: 0.8703
#    Epoch 25/80 [93s] | Train Loss: 0.0580 | Val Loss: 0.0723 | Val Dice: 0.8866
#    Epoch 26/80 [130s] | Train Loss: 0.0532 | Val Loss: 0.0700 | Val Dice: 0.8971 -> Новый лучший Val Dice
#    Epoch 27/80 [74s] | Train Loss: 0.0526 | Val Loss: 0.0695 | Val Dice: 0.8986 -> Новый лучший Val Dice
#    Epoch 28/80 [89s] | Train Loss: 0.0553 | Val Loss: 0.0753 | Val Dice: 0.8843
#    Epoch 29/80 [77s] | Train Loss: 0.0531 | Val Loss: 0.0725 | Val Dice: 0.8961
#    Epoch 30/80 [71s] | Train Loss: 0.0557 | Val Loss: 0.0745 | Val Dice: 0.8790
#    Epoch 31/80 [69s] | Train Loss: 0.0526 | Val Loss: 0.0774 | Val Dice: 0.8813
#    Epoch 32/80 [71s] | Train Loss: 0.0520 | Val Loss: 0.0744 | Val Dice: 0.8840
#    Epoch 33/80 [66s] | Train Loss: 0.0509 | Val Loss: 0.0734 | Val Dice: 0.8858
#    Epoch 34/80 [67s] | Train Loss: 0.0534 | Val Loss: 0.0778 | Val Dice: 0.8770
#    Epoch 35/80 [71s] | Train Loss: 0.0483 | Val Loss: 0.0703 | Val Dice: 0.8974
#    Epoch 36/80 [78s] | Train Loss: 0.0467 | Val Loss: 0.0726 | Val Dice: 0.8910
#    Epoch 37/80 [84s] | Train Loss: 0.0458 | Val Loss: 0.0680 | Val Dice: 0.9015 -> Новый лучший Val Dice
#    Epoch 38/80 [80s] | Train Loss: 0.0505 | Val Loss: 0.0748 | Val Dice: 0.8914
#    Epoch 39/80 [77s] | Train Loss: 0.0465 | Val Loss: 0.0663 | Val Dice: 0.9018 -> Новый лучший Val Dice
#    Epoch 40/80 [74s] | Train Loss: 0.0489 | Val Loss: 0.0711 | Val Dice: 0.8926
#    Epoch 41/80 [60s] | Train Loss: 0.0494 | Val Loss: 0.0714 | Val Dice: 0.8932
#    Epoch 42/80 [60s] | Train Loss: 0.0443 | Val Loss: 0.0690 | Val Dice: 0.9040 -> Новый лучший Val Dice
#    Epoch 43/80 [61s] | Train Loss: 0.0445 | Val Loss: 0.0688 | Val Dice: 0.8995
#    Epoch 44/80 [70s] | Train Loss: 0.0422 | Val Loss: 0.0689 | Val Dice: 0.9003
#    Epoch 45/80 [62s] | Train Loss: 0.0402 | Val Loss: 0.0684 | Val Dice: 0.9035
#    Epoch 46/80 [63s] | Train Loss: 0.0389 | Val Loss: 0.0700 | Val Dice: 0.9020
#    Epoch 47/80 [63s] | Train Loss: 0.0392 | Val Loss: 0.0663 | Val Dice: 0.9040 -> Новый лучший Val Dice
#    Epoch 48/80 [64s] | Train Loss: 0.0388 | Val Loss: 0.0670 | Val Dice: 0.9062 -> Новый лучший Val Dice
#    Epoch 49/80 [64s] | Train Loss: 0.0375 | Val Loss: 0.0689 | Val Dice: 0.9058
#    Epoch 50/80 [63s] | Train Loss: 0.0366 | Val Loss: 0.0674 | Val Dice: 0.9057
#    Epoch 51/80 [68s] | Train Loss: 0.0363 | Val Loss: 0.0668 | Val Dice: 0.9096 -> Новый лучший Val Dice
#    Epoch 52/80 [65s] | Train Loss: 0.0356 | Val Loss: 0.0670 | Val Dice: 0.9077
#    Epoch 53/80 [60s] | Train Loss: 0.0352 | Val Loss: 0.0643 | Val Dice: 0.9115 -> Новый лучший Val Dice
#    Epoch 54/80 [65s] | Train Loss: 0.0343 | Val Loss: 0.0668 | Val Dice: 0.9074
#    Epoch 55/80 [59s] | Train Loss: 0.0350 | Val Loss: 0.0683 | Val Dice: 0.9053
#    Epoch 56/80 [59s] | Train Loss: 0.0342 | Val Loss: 0.0679 | Val Dice: 0.9046
#    Epoch 57/80 [59s] | Train Loss: 0.0348 | Val Loss: 0.0653 | Val Dice: 0.9108
#    Epoch 58/80 [63s] | Train Loss: 0.0343 | Val Loss: 0.0688 | Val Dice: 0.9053
#    Epoch 59/80 [92s] | Train Loss: 0.0329 | Val Loss: 0.0673 | Val Dice: 0.9088
#    Epoch 60/80 [80s] | Train Loss: 0.0328 | Val Loss: 0.0666 | Val Dice: 0.9110
#    Epoch 61/80 [63s] | Train Loss: 0.0321 | Val Loss: 0.0677 | Val Dice: 0.9106
#    Epoch 62/80 [64s] | Train Loss: 0.0318 | Val Loss: 0.0663 | Val Dice: 0.9139 -> Новый лучший Val Dice
#    Epoch 63/80 [64s] | Train Loss: 0.0313 | Val Loss: 0.0656 | Val Dice: 0.9147 -> Новый лучший Val Dice
#    Epoch 64/80 [61s] | Train Loss: 0.0310 | Val Loss: 0.0657 | Val Dice: 0.9144
#    Epoch 65/80 [60s] | Train Loss: 0.0310 | Val Loss: 0.0682 | Val Dice: 0.9101
#    Epoch 66/80 [59s] | Train Loss: 0.0313 | Val Loss: 0.0667 | Val Dice: 0.9106
#    Epoch 67/80 [59s] | Train Loss: 0.0304 | Val Loss: 0.0656 | Val Dice: 0.9144
#    Epoch 68/80 [59s] | Train Loss: 0.0302 | Val Loss: 0.0666 | Val Dice: 0.9124
#    Epoch 69/80 [59s] | Train Loss: 0.0304 | Val Loss: 0.0665 | Val Dice: 0.9130
#    Epoch 70/80 [60s] | Train Loss: 0.0299 | Val Loss: 0.0670 | Val Dice: 0.9120
#    Epoch 71/80 [58s] | Train Loss: 0.0292 | Val Loss: 0.0666 | Val Dice: 0.9133
#    Epoch 72/80 [58s] | Train Loss: 0.0295 | Val Loss: 0.0670 | Val Dice: 0.9129
#    Epoch 73/80 [59s] | Train Loss: 0.0293 | Val Loss: 0.0666 | Val Dice: 0.9132
#    Epoch 74/80 [60s] | Train Loss: 0.0296 | Val Loss: 0.0665 | Val Dice: 0.9136
#    Epoch 75/80 [62s] | Train Loss: 0.0297 | Val Loss: 0.0660 | Val Dice: 0.9140
#    Epoch 76/80 [62s] | Train Loss: 0.0293 | Val Loss: 0.0661 | Val Dice: 0.9137
#    Epoch 77/80 [59s] | Train Loss: 0.0290 | Val Loss: 0.0663 | Val Dice: 0.9138
#    Epoch 78/80 [60s] | Train Loss: 0.0294 | Val Loss: 0.0663 | Val Dice: 0.9137
#    Epoch 79/80 [61s] | Train Loss: 0.0292 | Val Loss: 0.0662 | Val Dice: 0.9138
#    Epoch 80/80 [61s] | Train Loss: 0.0293 | Val Loss: 0.0662 | Val Dice: 0.9138
# ✅ Fold 4 завершен. Лучший Dice: 0.9147 на эпохе 63. Сохранено: conf3_deeplab_convnext_fold4.pth
#
# --- Обучение Fold 5/5 ---
#    Epoch 01/80 [61s] | Train Loss: 0.4193 | Val Loss: 0.3706 | Val Dice: 0.7050 -> Новый лучший Val Dice
#    Epoch 02/80 [60s] | Train Loss: 0.3266 | Val Loss: 0.2711 | Val Dice: 0.8096 -> Новый лучший Val Dice
#    Epoch 03/80 [60s] | Train Loss: 0.2517 | Val Loss: 0.2271 | Val Dice: 0.7877
#    Epoch 04/80 [60s] | Train Loss: 0.1861 | Val Loss: 0.1497 | Val Dice: 0.8363 -> Новый лучший Val Dice
#    Epoch 05/80 [76s] | Train Loss: 0.1584 | Val Loss: 0.1418 | Val Dice: 0.8279
#    Epoch 06/80 [68s] | Train Loss: 0.1356 | Val Loss: 0.1315 | Val Dice: 0.8341
#    Epoch 07/80 [62s] | Train Loss: 0.1147 | Val Loss: 0.1086 | Val Dice: 0.8309
#    Epoch 08/80 [62s] | Train Loss: 0.1086 | Val Loss: 0.0950 | Val Dice: 0.8516 -> Новый лучший Val Dice
#    Epoch 09/80 [63s] | Train Loss: 0.1016 | Val Loss: 0.0930 | Val Dice: 0.8580 -> Новый лучший Val Dice
#    Epoch 10/80 [64s] | Train Loss: 0.0985 | Val Loss: 0.0780 | Val Dice: 0.8682 -> Новый лучший Val Dice
#    Epoch 11/80 [66s] | Train Loss: 0.0868 | Val Loss: 0.0760 | Val Dice: 0.8728 -> Новый лучший Val Dice
#    Epoch 12/80 [64s] | Train Loss: 0.0864 | Val Loss: 0.0752 | Val Dice: 0.8710
#    Epoch 13/80 [65s] | Train Loss: 0.0788 | Val Loss: 0.0753 | Val Dice: 0.8743 -> Новый лучший Val Dice
#    Epoch 14/80 [62s] | Train Loss: 0.0834 | Val Loss: 0.0837 | Val Dice: 0.8663
#    Epoch 15/80 [61s] | Train Loss: 0.0799 | Val Loss: 0.0709 | Val Dice: 0.8830 -> Новый лучший Val Dice
#    Epoch 16/80 [62s] | Train Loss: 0.0757 | Val Loss: 0.0800 | Val Dice: 0.8678
#    Epoch 17/80 [61s] | Train Loss: 0.0728 | Val Loss: 0.0770 | Val Dice: 0.8726
#    Epoch 18/80 [62s] | Train Loss: 0.0675 | Val Loss: 0.0708 | Val Dice: 0.8827
#    Epoch 19/80 [61s] | Train Loss: 0.0617 | Val Loss: 0.0705 | Val Dice: 0.8753
#    Epoch 20/80 [58s] | Train Loss: 0.0648 | Val Loss: 0.0704 | Val Dice: 0.8819
#    Epoch 21/80 [62s] | Train Loss: 0.0612 | Val Loss: 0.0711 | Val Dice: 0.8896 -> Новый лучший Val Dice
#    Epoch 22/80 [68s] | Train Loss: 0.0614 | Val Loss: 0.0697 | Val Dice: 0.8862
#    Epoch 23/80 [63s] | Train Loss: 0.0616 | Val Loss: 0.0798 | Val Dice: 0.8759
#    Epoch 24/80 [59s] | Train Loss: 0.0583 | Val Loss: 0.0613 | Val Dice: 0.8987 -> Новый лучший Val Dice
#    Epoch 25/80 [59s] | Train Loss: 0.0597 | Val Loss: 0.0659 | Val Dice: 0.8751
#    Epoch 26/80 [59s] | Train Loss: 0.0628 | Val Loss: 0.0712 | Val Dice: 0.8782
#    Epoch 27/80 [60s] | Train Loss: 0.0638 | Val Loss: 0.0633 | Val Dice: 0.8952
#    Epoch 28/80 [63s] | Train Loss: 0.0570 | Val Loss: 0.0610 | Val Dice: 0.8956
#    Epoch 29/80 [66s] | Train Loss: 0.0560 | Val Loss: 0.0642 | Val Dice: 0.8946
#    Epoch 30/80 [64s] | Train Loss: 0.0568 | Val Loss: 0.0645 | Val Dice: 0.8839
#    Epoch 31/80 [63s] | Train Loss: 0.0555 | Val Loss: 0.0665 | Val Dice: 0.8885
#    Epoch 32/80 [63s] | Train Loss: 0.0501 | Val Loss: 0.0657 | Val Dice: 0.8957
#    Epoch 33/80 [64s] | Train Loss: 0.0494 | Val Loss: 0.0631 | Val Dice: 0.8946
#    Epoch 34/80 [60s] | Train Loss: 0.0453 | Val Loss: 0.0613 | Val Dice: 0.8986
#    Epoch 35/80 [62s] | Train Loss: 0.0474 | Val Loss: 0.0642 | Val Dice: 0.8893
#    Epoch 36/80 [62s] | Train Loss: 0.0456 | Val Loss: 0.0626 | Val Dice: 0.8919
#    Epoch 37/80 [68s] | Train Loss: 0.0424 | Val Loss: 0.0582 | Val Dice: 0.9002 -> Новый лучший Val Dice
#    Epoch 38/80 [68s] | Train Loss: 0.0431 | Val Loss: 0.0578 | Val Dice: 0.9055 -> Новый лучший Val Dice
#    Epoch 39/80 [73s] | Train Loss: 0.0435 | Val Loss: 0.0587 | Val Dice: 0.8948
#    Epoch 40/80 [84s] | Train Loss: 0.0425 | Val Loss: 0.0571 | Val Dice: 0.9063 -> Новый лучший Val Dice
#    Epoch 41/80 [72s] | Train Loss: 0.0455 | Val Loss: 0.0649 | Val Dice: 0.8919
#    Epoch 42/80 [64s] | Train Loss: 0.0487 | Val Loss: 0.0627 | Val Dice: 0.9024
#    Epoch 43/80 [65s] | Train Loss: 0.0439 | Val Loss: 0.0584 | Val Dice: 0.8991
#    Epoch 44/80 [65s] | Train Loss: 0.0402 | Val Loss: 0.0562 | Val Dice: 0.9042
#    Epoch 45/80 [59s] | Train Loss: 0.0397 | Val Loss: 0.0593 | Val Dice: 0.8967
#    Epoch 46/80 [60s] | Train Loss: 0.0391 | Val Loss: 0.0563 | Val Dice: 0.9084 -> Новый лучший Val Dice
#    Epoch 47/80 [61s] | Train Loss: 0.0393 | Val Loss: 0.0578 | Val Dice: 0.9027
#    Epoch 48/80 [62s] | Train Loss: 0.0378 | Val Loss: 0.0575 | Val Dice: 0.9025
#    Epoch 49/80 [62s] | Train Loss: 0.0369 | Val Loss: 0.0559 | Val Dice: 0.9064
#    Epoch 50/80 [60s] | Train Loss: 0.0365 | Val Loss: 0.0592 | Val Dice: 0.9015
#    Epoch 51/80 [63s] | Train Loss: 0.0348 | Val Loss: 0.0572 | Val Dice: 0.9096 -> Новый лучший Val Dice
#    Epoch 52/80 [61s] | Train Loss: 0.0350 | Val Loss: 0.0572 | Val Dice: 0.9072
#    Epoch 53/80 [64s] | Train Loss: 0.0349 | Val Loss: 0.0557 | Val Dice: 0.9114 -> Новый лучший Val Dice
#    Epoch 54/80 [69s] | Train Loss: 0.0334 | Val Loss: 0.0560 | Val Dice: 0.9101
#    Epoch 55/80 [69s] | Train Loss: 0.0333 | Val Loss: 0.0548 | Val Dice: 0.9103
#    Epoch 56/80 [70s] | Train Loss: 0.0331 | Val Loss: 0.0578 | Val Dice: 0.9050
#    Epoch 57/80 [68s] | Train Loss: 0.0336 | Val Loss: 0.0560 | Val Dice: 0.9065
#    Epoch 58/80 [68s] | Train Loss: 0.0320 | Val Loss: 0.0563 | Val Dice: 0.9095
#    Epoch 59/80 [75s] | Train Loss: 0.0320 | Val Loss: 0.0556 | Val Dice: 0.9119 -> Новый лучший Val Dice
#    Epoch 60/80 [73s] | Train Loss: 0.0312 | Val Loss: 0.0551 | Val Dice: 0.9125 -> Новый лучший Val Dice
#    Epoch 61/80 [71s] | Train Loss: 0.0304 | Val Loss: 0.0559 | Val Dice: 0.9106
#    Epoch 62/80 [76s] | Train Loss: 0.0311 | Val Loss: 0.0568 | Val Dice: 0.9103
#    Epoch 63/80 [65s] | Train Loss: 0.0306 | Val Loss: 0.0576 | Val Dice: 0.9100
#    Epoch 64/80 [61s] | Train Loss: 0.0299 | Val Loss: 0.0578 | Val Dice: 0.9096
#    Epoch 65/80 [59s] | Train Loss: 0.0292 | Val Loss: 0.0582 | Val Dice: 0.9084
#    Epoch 66/80 [59s] | Train Loss: 0.0289 | Val Loss: 0.0575 | Val Dice: 0.9096
#    Epoch 67/80 [59s] | Train Loss: 0.0289 | Val Loss: 0.0563 | Val Dice: 0.9114
#    Epoch 68/80 [59s] | Train Loss: 0.0289 | Val Loss: 0.0568 | Val Dice: 0.9109
#    Epoch 69/80 [59s] | Train Loss: 0.0289 | Val Loss: 0.0575 | Val Dice: 0.9105
#    Epoch 70/80 [59s] | Train Loss: 0.0286 | Val Loss: 0.0574 | Val Dice: 0.9106
#    Epoch 71/80 [58s] | Train Loss: 0.0288 | Val Loss: 0.0575 | Val Dice: 0.9108
#    Epoch 72/80 [58s] | Train Loss: 0.0293 | Val Loss: 0.0572 | Val Dice: 0.9111
#    Epoch 73/80 [59s] | Train Loss: 0.0289 | Val Loss: 0.0571 | Val Dice: 0.9112
#    Epoch 74/80 [60s] | Train Loss: 0.0280 | Val Loss: 0.0571 | Val Dice: 0.9116
#    Epoch 75/80 [59s] | Train Loss: 0.0287 | Val Loss: 0.0574 | Val Dice: 0.9114
#    Epoch 76/80 [59s] | Train Loss: 0.0279 | Val Loss: 0.0572 | Val Dice: 0.9114
#    Epoch 77/80 [59s] | Train Loss: 0.0277 | Val Loss: 0.0573 | Val Dice: 0.9114
#    Epoch 78/80 [59s] | Train Loss: 0.0279 | Val Loss: 0.0573 | Val Dice: 0.9113
#    Epoch 79/80 [59s] | Train Loss: 0.0281 | Val Loss: 0.0572 | Val Dice: 0.9113
#    Epoch 80/80 [60s] | Train Loss: 0.0280 | Val Loss: 0.0573 | Val Dice: 0.9113
# ✅ Fold 5 завершен. Лучший Dice: 0.9125 на эпохе 60. Сохранено: conf3_deeplab_convnext_fold5.pth
#
# 🏆 Итоги conf3_deeplab_convnext: Средний Dice по всем фолдам: 0.9085
